# %%
KARUR SHANTHI
COLOR DETECTION USING OPEN CV

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import cv2
from collections import Counter
import os
import pandas as pd

# %%
image=plt.imread(r'C:\Users\W10-Dell\Downloads\colour.jpg')

# %%
plt.imshow(image)

# %%
img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_image, cmap='gray')

# %%
modified_image = cv2.resize(image, (600, 400), interpolation = cv2.INTER_AREA)
modified_image = modified_image.reshape(modified_image.shape[0]*modified_image.shape[1], 3)

# %%
number_of_colors=5
clf = KMeans(n_clusters = number_of_colors)
labels = clf.fit_predict(modified_image)

# %%
img=img.reshape((img.shape[1]*img.shape[0],3))

# %%
kmeans=KMeans(n_clusters=5)
s=kmeans.fit(img)
print(s)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
labels=kmeans.labels_
print(labels)
labels=list(labels)
# Out:
# [3 1 1 ... 1 1 0]

# %%
center=kmeans.cluster_centers_

# %%
percent=[]
for i in range(len(center)):
  j=labels.count(i)
  j=j/(len(labels))
  percent.append(j)
print(percent)
# Out:
# [0.2683663160396981, 0.27825518511915376, 0.0962322457954478, 0.1908777559874012, 0.16626849705829916]

# %%
plt.pie(percent,colors=np.array(center/255),labels=np.arange(len(centroid)))
plt.show()
